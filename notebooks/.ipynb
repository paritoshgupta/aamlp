# %% [markdown]
# # Import libraries

# %%
# !pip install category_encoders
# !pip install lightgbm
# !pip install pillow
# !pip install opencv-python
# !pip install pydicom
# !pip install lightgbm
# !pip install xgboost
# !pip install hyperopt

import os
from logging import getLogger, INFO, StreamHandler, FileHandler, Formatter
from functools import partial
from sklearn import preprocessing
import numpy as np
import pandas as pd
import random
import math
from sklearn.ensemble import GradientBoostingRegressor

from tqdm.notebook import tqdm

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import StratifiedKFold, GroupKFold, KFold
from sklearn.metrics import mean_squared_error
# import category_encoders as ce

from PIL import Image
import cv2
import pydicom

import torch

import lightgbm as lgb
from sklearn.linear_model import Ridge

import warnings
warnings.filterwarnings("ignore")

# !pip install hyperopt
import numpy as np
import pandas as pd
from functools import partial
import xgboost as xgb
from numpy.ma import MaskedArray
import sklearn.utils.fixes
sklearn.utils.fixes.MaskedArray = MaskedArray

import tensorflow as tf
import tensorflow.keras.backend as K
import tensorflow.keras.layers as Layers
import tensorflow.keras.models as Models
import warnings
warnings.filterwarnings('ignore') #Ignore "future" warnings and Data-Frame-Slicing warnings.

from sklearn import metrics
from sklearn import ensemble
from sklearn import model_selection
import hyperopt
from hyperopt import hp, fmin, tpe, Trials
from hyperopt.pyll.base import scope

def seed_everything(seed = 2020): 
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    
seed_everything(42)

# %% [markdown]
# # Config

# %%
ROOT = '../input/osic-pulmonary-fibrosis-progression'

# %% [markdown]
# # Read data

# %% [markdown]
# ## Train data cleanup

# %%
train_df = pd.read_csv(f'{ROOT}/train.csv')
print(f'Train data has {train_df.shape[0]} rows and {train_df.shape[1]} columnns and looks like this:')
train_df.sample(10)
# Out:
# Train data has 1549 rows and 7 columnns and looks like this:
#                         Patient  Weeks   FVC     Percent  Age     Sex  \
# 350   ID00099637202206203080121    102  2833   79.382425   68    Male
# 650   ID00169637202238024117706     40  2486  105.009715   66  Female
# 1178  ID00329637202285906759848     43  2848   67.264998   69    Male
# 271   ID00077637202199102000916      6  3121   80.804681   70    Male
# 162   ID00047637202184938901501      6  3370   91.476656   68    Male
# 968   ID00251637202267455595113     37  1937   58.049628   88    Male
# 59    ID00015637202177877247924     40  2697   69.725957   71    Male
# 306   ID00089637202204675567570      7  2478   57.967624   63    Male
# 1511  ID00419637202311204720264     43  2793   64.911221   73    Male
# 462   ID00124637202217596410344     72  3454   86.194849   60    Male
#
#      SmokingStatus
# 350      Ex-smoker
# 650   Never smoked
# 1178     Ex-smoker
# 271      Ex-smoker
# 162      Ex-smoker
# 968      Ex-smoker
# 59       Ex-smoker
# 306   Never smoked
# 1511     Ex-smoker
# 462      Ex-smoker

# %%
dupRows_df = train_df[train_df.duplicated(subset = ['Patient', 'Weeks'], keep = False )]
dupRows_df
# Out:
#                         Patient  Weeks   FVC    Percent  Age     Sex  \
# 166   ID00048637202185016727717      9  1375  60.059404   70  Female
# 167   ID00048637202185016727717      9  1477  64.514720   70  Female
# 226   ID00068637202190879923934     11  2794  82.633385   73    Male
# 227   ID00068637202190879923934     11  2827  83.609369   73    Male
# 306   ID00089637202204675567570      7  2478  57.967624   63    Male
# 307   ID00089637202204675567570      7  2539  59.394592   63    Male
# 465   ID00125637202218590429387      8  2349  53.757781   65    Male
# 466   ID00125637202218590429387      8  2584  59.135848   65    Male
# 750   ID00199637202248141386743      5  2672  64.728682   62    Male
# 751   ID00199637202248141386743      5  2683  64.995155   62    Male
# 920   ID00240637202264138860065      5  2991  78.421605   63    Male
# 921   ID00240637202264138860065      5  3132  82.118511   63    Male
# 1521  ID00421637202311550012437     70  2628  78.720345   68    Male
# 1522  ID00421637202311550012437     70  2719  81.446202   68    Male
#
#      SmokingStatus
# 166   Never smoked
# 167   Never smoked
# 226      Ex-smoker
# 227      Ex-smoker
# 306   Never smoked
# 307   Never smoked
# 465   Never smoked
# 466   Never smoked
# 750      Ex-smoker
# 751      Ex-smoker
# 920      Ex-smoker
# 921      Ex-smoker
# 1521     Ex-smoker
# 1522     Ex-smoker

# %%
train_df_tmp1 = train_df.groupby(['Patient', 'Weeks']).mean().reset_index()
train_df_tmp2 = train_df[['Patient', 'Weeks', 'Sex', 'SmokingStatus']].drop_duplicates().reset_index(drop=True)
print(train_df_tmp1.shape)
print(train_df_tmp2.shape)
df_train = pd.merge(train_df_tmp1, train_df_tmp2, on=["Patient", "Weeks"], how="inner")
print(df_train.shape)
df_train.head()
# Out:
# (1542, 5)
# (1542, 4)
# (1542, 7)
#                      Patient  Weeks     FVC    Percent   Age   Sex  \
# 0  ID00007637202177411956430     -4  2315.0  58.253649  79.0  Male
# 1  ID00007637202177411956430      5  2214.0  55.712129  79.0  Male
# 2  ID00007637202177411956430      7  2061.0  51.862104  79.0  Male
# 3  ID00007637202177411956430      9  2144.0  53.950679  79.0  Male
# 4  ID00007637202177411956430     11  2069.0  52.063412  79.0  Male
#
#   SmokingStatus
# 0     Ex-smoker
# 1     Ex-smoker
# 2     Ex-smoker
# 3     Ex-smoker
# 4     Ex-smoker

# %% [markdown]
# ## Test data

# %%
test_df = pd.read_csv(f'{ROOT}/test.csv')
print(f'Test data has {test_df.shape[0]} rows and {test_df.shape[1]} columnns, has no duplicates and looks like this:')
test_df.head()
# Out:
# Test data has 5 rows and 7 columnns, has no duplicates and looks like this:
#                      Patient  Weeks   FVC    Percent  Age   Sex SmokingStatus
# 0  ID00419637202311204720264      6  3020  70.186855   73  Male     Ex-smoker
# 1  ID00421637202311550012437     15  2739  82.045291   68  Male     Ex-smoker
# 2  ID00422637202311677017371      6  1930  76.672493   73  Male     Ex-smoker
# 3  ID00423637202312137826377     17  3294  79.258903   72  Male     Ex-smoker
# 4  ID00426637202313170790466      0  2925  71.824968   73  Male  Never smoked

# %% [markdown]
# ## Submission data

# %%
sub_df = pd.read_csv(f"{ROOT}/sample_submission.csv")

print(f"The sample submission contains: {sub_df.shape[0]} rows and {sub_df.shape[1]} columns.")
# Out:
# The sample submission contains: 730 rows and 3 columns.

# %%
# split Patient_Week Column and re-arrage columns
sub_df[['Patient','Weeks']] = sub_df.Patient_Week.str.split("_",expand = True)
sub_df =  sub_df[['Patient','Weeks','Confidence', 'Patient_Week']]
sub_df = sub_df.merge(test_df.drop('Weeks', axis = 1), on = "Patient")
sub_df.head(20)
# Out:
#                       Patient Weeks  Confidence  \
# 0   ID00419637202311204720264   -12         100
# 1   ID00419637202311204720264   -11         100
# 2   ID00419637202311204720264   -10         100
# 3   ID00419637202311204720264    -9         100
# 4   ID00419637202311204720264    -8         100
# 5   ID00419637202311204720264    -7         100
# 6   ID00419637202311204720264    -6         100
# 7   ID00419637202311204720264    -5         100
# 8   ID00419637202311204720264    -4         100
# 9   ID00419637202311204720264    -3         100
# 10  ID00419637202311204720264    -2         100
# 11  ID00419637202311204720264    -1         100
# 12  ID00419637202311204720264     0         100
# 13  ID00419637202311204720264     1         100
# 14  ID00419637202311204720264     2         100
# 15  ID00419637202311204720264     3         100
# 16  ID00419637202311204720264     4         100
# 17  ID00419637202311204720264     5         100
# 18  ID00419637202311204720264     6         100
# 19  ID00419637202311204720264     7         100
#
#                      Patient_Week   FVC    Percent  Age   Sex SmokingStatus
# 0   ID00419637202311204720264_-12  3020  70.186855   73  Male     Ex-smoker
# 1   ID00419637202311204720264_-11  3020  70.186855   73  Male     Ex-smoker
# 2   ID00419637202311204720264_-10  3020  70.186855   73  Male     Ex-smoker
# 3    ID00419637202311204720264_-9  3020  70.186855   73  Male     Ex-smoker
# 4    ID00419637202311204720264_-8  3020  70.186855   73  Male     Ex-smoker
# 5    ID00419637202311204720264_-7  3020  70.186855   73  Male     Ex-smoker
# 6    ID00419637202311204720264_-6  3020  70.186855   73  Male     Ex-smoker
# 7    ID00419637202311204720264_-5  3020  70.186855   73  Male     Ex-smoker
# 8    ID00419637202311204720264_-4  3020  70.186855   73  Male     Ex-smoker
# 9    ID00419637202311204720264_-3  3020  70.186855   73  Male     Ex-smoker
# 10   ID00419637202311204720264_-2  3020  70.186855   73  Male     Ex-smoker
# 11   ID00419637202311204720264_-1  3020  70.186855   73  Male     Ex-smoker
# 12    ID00419637202311204720264_0  3020  70.186855   73  Male     Ex-smoker
# 13    ID00419637202311204720264_1  3020  70.186855   73  Male     Ex-smoker
# 14    ID00419637202311204720264_2  3020  70.186855   73  Male     Ex-smoker
# 15    ID00419637202311204720264_3  3020  70.186855   73  Male     Ex-smoker
# 16    ID00419637202311204720264_4  3020  70.186855   73  Male     Ex-smoker
# 17    ID00419637202311204720264_5  3020  70.186855   73  Male     Ex-smoker
# 18    ID00419637202311204720264_6  3020  70.186855   73  Male     Ex-smoker
# 19    ID00419637202311204720264_7  3020  70.186855   73  Male     Ex-smoker

# %% [markdown]
# ## ADS prep

# %%
# introduce a column to indicate the source (train/test) for the data
train_df['Source'] = 'train'
sub_df['Source'] = 'test'

data_df = train_df.append([sub_df])
# data_df.reset_index(inplace = True)
print(data_df.shape)
data_df.head()
# Out:
# (2279, 10)
#                      Patient Weeks   FVC    Percent  Age   Sex SmokingStatus  \
# 0  ID00007637202177411956430    -4  2315  58.253649   79  Male     Ex-smoker
# 1  ID00007637202177411956430     5  2214  55.712129   79  Male     Ex-smoker
# 2  ID00007637202177411956430     7  2061  51.862104   79  Male     Ex-smoker
# 3  ID00007637202177411956430     9  2144  53.950679   79  Male     Ex-smoker
# 4  ID00007637202177411956430    11  2069  52.063412   79  Male     Ex-smoker
#
#   Source  Confidence Patient_Week
# 0  train         NaN          NaN
# 1  train         NaN          NaN
# 2  train         NaN          NaN
# 3  train         NaN          NaN
# 4  train         NaN          NaN

# %%
sub_df
# Out:
#                        Patient Weeks  Confidence  \
# 0    ID00419637202311204720264   -12         100
# 1    ID00419637202311204720264   -11         100
# 2    ID00419637202311204720264   -10         100
# 3    ID00419637202311204720264    -9         100
# 4    ID00419637202311204720264    -8         100
# ..                         ...   ...         ...
# 725  ID00426637202313170790466   129         100
# 726  ID00426637202313170790466   130         100
# 727  ID00426637202313170790466   131         100
# 728  ID00426637202313170790466   132         100
# 729  ID00426637202313170790466   133         100
#
#                       Patient_Week   FVC    Percent  Age   Sex SmokingStatus  \
# 0    ID00419637202311204720264_-12  3020  70.186855   73  Male     Ex-smoker
# 1    ID00419637202311204720264_-11  3020  70.186855   73  Male     Ex-smoker
# 2    ID00419637202311204720264_-10  3020  70.186855   73  Male     Ex-smoker
# 3     ID00419637202311204720264_-9  3020  70.186855   73  Male     Ex-smoker
# 4     ID00419637202311204720264_-8  3020  70.186855   73  Male     Ex-smoker
# ..                             ...   ...        ...  ...   ...           ...
# 725  ID00426637202313170790466_129  2925  71.824968   73  Male  Never smoked
# 726  ID00426637202313170790466_130  2925  71.824968   73  Male  Never smoked
# 727  ID00426637202313170790466_131  2925  71.824968   73  Male  Never smoked
# 728  ID00426637202313170790466_132  2925  71.824968   73  Male  Never smoked
# 729  ID00426637202313170790466_133  2925  71.824968   73  Male  Never smoked
#
#     Source
# 0     test
# 1     test
# 2     test
# 3     test
# 4     test
# ..     ...
# 725   test
# 726   test
# 727   test
# 728   test
# 729   test
#
# [730 rows x 10 columns]

# %%
def get_baseline_week(df):
    # make a copy to not change original df    
    _df = df.copy()
    # ensure all Weeks values are INT and not accidentaly saved as string
    _df['Weeks'] = _df['Weeks'].astype(int)
    # as test data is containing all weeks, 
    _df.loc[_df.Source == 'test','min_week'] = np.nan
    _df["min_week"] = _df.groupby('Patient')['Weeks'].transform('min')
    _df['baselined_week'] = _df['Weeks'] - _df['min_week']
    
    return _df

# %%
data_df = get_baseline_week(data_df)
data_df.head()
# Out:
#                      Patient  Weeks   FVC    Percent  Age   Sex SmokingStatus  \
# 0  ID00007637202177411956430     -4  2315  58.253649   79  Male     Ex-smoker
# 1  ID00007637202177411956430      5  2214  55.712129   79  Male     Ex-smoker
# 2  ID00007637202177411956430      7  2061  51.862104   79  Male     Ex-smoker
# 3  ID00007637202177411956430      9  2144  53.950679   79  Male     Ex-smoker
# 4  ID00007637202177411956430     11  2069  52.063412   79  Male     Ex-smoker
#
#   Source  Confidence Patient_Week  min_week  baselined_week
# 0  train         NaN          NaN        -4               0
# 1  train         NaN          NaN        -4               9
# 2  train         NaN          NaN        -4              11
# 3  train         NaN          NaN        -4              13
# 4  train         NaN          NaN        -4              15

# %%
def get_baseline_FVC(df):
    # same as above
    _df = df.copy()
    base = _df.loc[_df.Weeks == _df.min_week]
    base = base[['Patient','FVC']].copy()
    base.columns = ['Patient','base_FVC']
    
    # add a row which contains the cumulated sum of rows for each patient
    base['nb'] = 1
    base['nb'] = base.groupby('Patient')['nb'].transform('cumsum')
    
    # drop all except the first row for each patient (= unique rows!), containing the min_week
    base = base[base.nb == 1]
    base.drop('nb', axis = 1, inplace = True)
    
    # merge the rows containing the base_FVC on the original _df
    _df = _df.merge(base, on = 'Patient', how = 'left')    
    _df.drop(['min_week'], axis = 1)
    
    return _df

# %%
data_df = get_baseline_FVC(data_df)
data_df.head()
data_df.columns
# Out:
# Index(['Patient', 'Weeks', 'FVC', 'Percent', 'Age', 'Sex', 'SmokingStatus',
#        'Source', 'Confidence', 'Patient_Week', 'min_week', 'baselined_week',
#        'base_FVC'],
#       dtype='object')

# %% [markdown]
# ## Train data K fold prepm

# %%
TARGET = 'FVC'
N_FOLDS = 4

# %%
df_train = data_df[data_df['Source']=="train"].reset_index(drop=True)
sub_df = data_df[data_df['Source']=="test"].reset_index(drop=True)
group_k_fold = GroupKFold(n_splits=N_FOLDS)
groups = df_train['Patient'].values
for fold, (train_index, valid_index) in enumerate(group_k_fold.split(df_train, df_train[TARGET], groups)):
    df_train.loc[valid_index, 'fold'] = int(fold)
df_train['kfold'] = df_train['fold'].astype(int)
df_train.head()
df_train.to_csv(f'{ROOT}/ads_4_folds.csv', index=False)
sub_df.to_csv(f'{ROOT}/sub_df.csv', index=False)

# %%
df_train
# Out:
#                         Patient  Weeks   FVC    Percent  Age   Sex  \
# 0     ID00007637202177411956430     -4  2315  58.253649   79  Male
# 1     ID00007637202177411956430      5  2214  55.712129   79  Male
# 2     ID00007637202177411956430      7  2061  51.862104   79  Male
# 3     ID00007637202177411956430      9  2144  53.950679   79  Male
# 4     ID00007637202177411956430     11  2069  52.063412   79  Male
# ...                         ...    ...   ...        ...  ...   ...
# 1544  ID00426637202313170790466     13  2712  66.594637   73  Male
# 1545  ID00426637202313170790466     19  2978  73.126412   73  Male
# 1546  ID00426637202313170790466     31  2908  71.407524   73  Male
# 1547  ID00426637202313170790466     43  2975  73.052745   73  Male
# 1548  ID00426637202313170790466     59  2774  68.117081   73  Male
#
#      SmokingStatus Source  Confidence Patient_Week  min_week  baselined_week  \
# 0        Ex-smoker  train         NaN          NaN        -4               0
# 1        Ex-smoker  train         NaN          NaN        -4               9
# 2        Ex-smoker  train         NaN          NaN        -4              11
# 3        Ex-smoker  train         NaN          NaN        -4              13
# 4        Ex-smoker  train         NaN          NaN        -4              15
# ...            ...    ...         ...          ...       ...             ...
# 1544  Never smoked  train         NaN          NaN       -12              25
# 1545  Never smoked  train         NaN          NaN       -12              31
# 1546  Never smoked  train         NaN          NaN       -12              43
# 1547  Never smoked  train         NaN          NaN       -12              55
# 1548  Never smoked  train         NaN          NaN       -12              71
#
#       base_FVC  fold  kfold
# 0         2315   1.0      1
# 1         2315   1.0      1
# 2         2315   1.0      1
# 3         2315   1.0      1
# 4         2315   1.0      1
# ...        ...   ...    ...
# 1544      2925   1.0      1
# 1545      2925   1.0      1
# 1546      2925   1.0      1
# 1547      2925   1.0      1
# 1548      2925   1.0      1
#
# [1549 rows x 15 columns]

# %% [markdown]
# # Modeling

# %%
df = pd.read_csv(f'{ROOT}/ads_4_folds.csv')
sub_df = pd.read_csv(f'{ROOT}/sub_df.csv')
print(df.shape)
df.head()
# Out:
# (1549, 15)
#                      Patient  Weeks   FVC    Percent  Age   Sex SmokingStatus  \
# 0  ID00007637202177411956430     -4  2315  58.253649   79  Male     Ex-smoker
# 1  ID00007637202177411956430      5  2214  55.712129   79  Male     Ex-smoker
# 2  ID00007637202177411956430      7  2061  51.862104   79  Male     Ex-smoker
# 3  ID00007637202177411956430      9  2144  53.950679   79  Male     Ex-smoker
# 4  ID00007637202177411956430     11  2069  52.063412   79  Male     Ex-smoker
#
#   Source  Confidence  Patient_Week  min_week  baselined_week  base_FVC  fold  \
# 0  train         NaN           NaN        -4               0      2315   1.0
# 1  train         NaN           NaN        -4               9      2315   1.0
# 2  train         NaN           NaN        -4              11      2315   1.0
# 3  train         NaN           NaN        -4              13      2315   1.0
# 4  train         NaN           NaN        -4              15      2315   1.0
#
#    kfold
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %% [markdown]
# ## filter relevant columns

# %%
df = df[['Patient', 'FVC', 'Age', 'Sex', 'SmokingStatus', 'baselined_week', 'base_FVC', 'kfold']]
df.head()
# Out:
#                      Patient   FVC  Age   Sex SmokingStatus  baselined_week  \
# 0  ID00007637202177411956430  2315   79  Male     Ex-smoker               0
# 1  ID00007637202177411956430  2214   79  Male     Ex-smoker               9
# 2  ID00007637202177411956430  2061   79  Male     Ex-smoker              11
# 3  ID00007637202177411956430  2144   79  Male     Ex-smoker              13
# 4  ID00007637202177411956430  2069   79  Male     Ex-smoker              15
#
#    base_FVC  kfold
# 0      2315      1
# 1      2315      1
# 2      2315      1
# 3      2315      1
# 4      2315      1

# %%
print(df['kfold'].unique())
df['kfold'].value_counts()
# Out:
# [1 0 3 2]
# 0    388
# 3    387
# 2    387
# 1    387
# Name: kfold, dtype: int64

# %%
features = [f for f in df.columns if f not in ["Patient", "kfold", "FVC"]]
print(features)
cat_features = ["Sex", "SmokingStatus"]

for col in cat_features:
    lbl = preprocessing.LabelEncoder()
    lbl.fit(df[col])
    df.loc[:, col] = lbl.transform(df[col])
    sub_df.loc[:, col] = lbl.transform(sub_df[col])
# Out:
# ['Age', 'Sex', 'SmokingStatus', 'baselined_week', 'base_FVC']

# %%
def optimize(params, x, y, groups):

    # initialize model with current parameters
    model = GradientBoostingRegressor(**params)

    group_k_fold = GroupKFold(n_splits=N_FOLDS)

    # initialize accuracy list
    rmse_errors = []
    
    for idx in group_k_fold.split(x, y, groups):
        train_idx, test_idx = idx[0], idx[1]
        xtrain = x[train_idx]
        ytrain = y[train_idx]

        xtest = x[test_idx]
        ytest = y[test_idx]

        # fit model on train data
        model.fit(xtrain, ytrain)

        # create predictions
        preds = model.predict(xtest)

        fold_rmse = np.sqrt(mean_squared_error(ytest, preds))
        rmse_errors.append(fold_rmse)
    
    return np.mean(rmse_errors)

# %%
quantiles = [0.15, 0.5, 0.85]

best_params_list = []
for quantile in quantiles:
    param_space = {
            'n_estimators': hp.randint('n_estimators',1000) ,
            'learning_rate': hp.loguniform('learning_rate',-3,1),
            'loss': 'quantile',
            'alpha': quantile

    }

    groups = df.Patient.values
    print(df[features].columns)
    X = df[features].values
    y = df[TARGET].values
    optimization_function = partial(optimize, x=X, y=y, groups = groups)
    # initialize Trials to keep logging information
    trials = Trials()

    # run hyperopt
    print(f"Starting HP tuning using hyperopt for quantile --> {quantile}")
    hopt = fmin(fn=optimization_function,
    space=param_space,
    algo=tpe.suggest,
    max_evals=2,
    trials=trials)
    
    print(f"Quantile --> {quantile}")
    print(hopt)
    best_params = dict(zip(list(hopt.keys()), list(hopt.values())))
    print(best_params)
    best_params_list.append(best_params)
# Out:
# Index(['Age', 'Sex', 'SmokingStatus', 'baselined_week', 'base_FVC'], dtype='object')
# Starting HP tuning using hyperopt for quantile --> 0.15
# 100%|██████████| 2/2 [00:03<00:00,  1.58s/trial, best loss: 320.4239288593862]
# Quantile --> 0.15
# {'learning_rate': 0.503218442053025, 'n_estimators': 197}
# {'learning_rate': 0.503218442053025, 'n_estimators': 197}
# Index(['Age', 'Sex', 'SmokingStatus', 'baselined_week', 'base_FVC'], dtype='object')
# Starting HP tuning using hyperopt for quantile --> 0.5
# 100%|██████████| 2/2 [00:03<00:00,  1.72s/trial, best loss: 273.8693221703783]
# Quantile --> 0.5
# {'learning_rate': 0.5872913234329212, 'n_estimators': 141}
# {'learning_rate': 0.5872913234329212, 'n_estimators': 141}
# Index(['Age', 'Sex', 'SmokingStatus', 'baselined_week', 'base_FVC'], dtype='object')
# Starting HP tuning using hyperopt for quantile --> 0.85
# 100%|██████████| 2/2 [00:04<00:00,  2.06s/trial, best loss: 481.3009582728591]
# Quantile --> 0.85
# {'learning_rate': 1.7111871622289212, 'n_estimators': 5}
# {'learning_rate': 1.7111871622289212, 'n_estimators': 5}

# %%
def run(fold):
    df_train = df[df.kfold !=0].reset_index(drop=True)
    # get validation data
    df_valid = df[df.kfold ==0].reset_index(drop=True)
    print(df_valid.shape)
    # get training data
    x_train = df_train[features]
    # get validation data
    x_valid = df_valid[features]
    x_test = sub_df[features]
    for q_ in range(len(best_params_list)):
        best_model = GradientBoostingRegressor(loss='quantile',
                          alpha=quantiles[q_],
                          n_estimators=best_params_list[q_]['n_estimators'],
                          learning_rate=best_params_list[q_]['learning_rate'])
        
        best_model.fit(x_train, df_train.FVC.values)
        pred = best_model.predict(x_valid).round(2)
        df_valid.loc[:, str('pred_' + str(quantiles[q_]))] = pred
        pred_test = best_model.predict(x_test).round(2)
        sub_df.loc[:, str('pred_' +str(fold) + "_" + str(quantiles[q_]))] = pred_test
    return df_valid, sub_df

# %%
df_tmp, sub_df = run(0)
# Out:
# (388, 8)

# %%
# sub_df
# df_tmp.groupby(['Patient', 'baselined_week'])
df_tmp

df_tmp = df_tmp.sort_values(['Patient', 'baselined_week']).groupby(['Patient']).apply(lambda x: x.tail(3)).reset_index(drop=True)
df_tmp['Confidence'] = df_tmp['pred_0.85'] - df_tmp['pred_0.15']
df_tmp['sigma_clipped'] = df_tmp['Confidence'].apply(lambda x: max(x, 70))
df_tmp['diff'] = abs(df_tmp['FVC'] - df_tmp['pred_0.5'])
df_tmp['delta'] = df_tmp['diff'].apply(lambda x: min(x, 1000))
df_tmp['score'] = -math.sqrt(2)*df_tmp['delta']/df_tmp['sigma_clipped'] - np.log(math.sqrt(2)*df_tmp['sigma_clipped'])

# %%
df_tmp.groupby("Patient")['score'].

# %%
df_tmp['Confidence'] = df_tmp['pred_0.85'] - df_tmp['pred_0.15']

df_tmp['sigma_clipped'] = df_tmp['Confidence'].apply(lambda x: max(x, 70))
df_tmp['diff'] = abs(df_tmp['FVC'] - df_tmp['pred_0.5'])
df_tmp['delta'] = df_tmp['diff'].apply(lambda x: min(x, 1000))
df_tmp['score'] = -math.sqrt(2)*df_tmp['delta']/df_tmp['sigma_clipped'] - np.log(math.sqrt(2)*df_tmp['sigma_clipped'])
score = df_tmp['score'].mean()
print(score)
df_tmp
# Out:
# -7.058978427527051
#                        Patient   FVC  Age  Sex  SmokingStatus  baselined_week  \
# 0    ID00009637202177434476278  3660   69    1              1               0
# 1    ID00009637202177434476278  3610   69    1              1               1
# 2    ID00009637202177434476278  3895   69    1              1               3
# 3    ID00009637202177434476278  3759   69    1              1               5
# 4    ID00009637202177434476278  3639   69    1              1               7
# ..                         ...   ...  ...  ...            ...             ...
# 383  ID00423637202312137826377  2661   72    1              1              35
# 384  ID00423637202312137826377  2778   72    1              1              42
# 385  ID00423637202312137826377  2516   72    1              1              54
# 386  ID00423637202312137826377  2432   72    1              1              65
# 387  ID00423637202312137826377  2578   72    1              1              82
#
#      base_FVC  kfold  pred_0.15  pred_0.5  pred_0.85  Confidence  \
# 0        3660      0    3398.55   3635.83    3697.90      299.35
# 1        3660      0    3305.68   3608.80    3707.44      401.76
# 2        3660      0    3249.31   3609.65    3736.62      487.31
# 3        3660      0    3222.51   3550.85    3728.85      506.34
# 4        3660      0    3211.70   3553.22    3741.93      530.23
# ..        ...    ...        ...       ...        ...         ...
# 383      3294      0    2981.27   3117.39    3344.31      363.04
# 384      3294      0    2920.38   3076.86    3324.01      403.63
# 385      3294      0    2965.24   3054.71    3319.50      354.26
# 386      3294      0    3186.31   3120.12    3204.73       18.42
# 387      3294      0    3133.08   3007.76    3152.99       19.91
#
#      sigma_clipped    diff   delta      score
# 0           299.35   24.17   24.17  -6.162373
# 1           401.76    1.20    1.20  -6.346653
# 2           487.31  285.35  285.35  -7.363583
# 3           506.34  208.15  208.15  -7.155147
# 4           530.23   85.78   85.78  -6.848674
# ..             ...     ...     ...        ...
# 383         363.04  456.39  456.39  -8.018943
# 384         403.63  298.86  298.86  -7.394199
# 385         354.26  538.71  538.71  -8.367147
# 386          70.00  688.12  688.12 -18.497192
# 387          70.00  429.76  429.76 -13.277532
#
# [388 rows x 16 columns]

# %%
df['pred_fvc'] = preds

# %%
df
# Out:
#                         Patient   FVC  Age  Sex  SmokingStatus  \
# 0     ID00007637202177411956430  2315   79    1              1
# 1     ID00007637202177411956430  2214   79    1              1
# 2     ID00007637202177411956430  2061   79    1              1
# 3     ID00007637202177411956430  2144   79    1              1
# 4     ID00007637202177411956430  2069   79    1              1
# ...                         ...   ...  ...  ...            ...
# 1544  ID00426637202313170790466  2712   73    1              2
# 1545  ID00426637202313170790466  2978   73    1              2
# 1546  ID00426637202313170790466  2908   73    1              2
# 1547  ID00426637202313170790466  2975   73    1              2
# 1548  ID00426637202313170790466  2774   73    1              2
#
#       baselined_week  base_FVC  kfold     pred_fvc
# 0                  0      2315      1  2285.417665
# 1                  9      2315      1  2144.766597
# 2                 11      2315      1  2077.089699
# 3                 13      2315      1  2070.528942
# 4                 15      2315      1  2055.044048
# ...              ...       ...    ...          ...
# 1544              25      2925      1  2712.452983
# 1545              31      2925      1  2738.629891
# 1546              43      2925      1  2664.112790
# 1547              55      2925      1  2682.610236
# 1548              71      2925      1  2773.999758
#
# [1549 rows x 9 columns]

# %%
best_params_list
# Out:
# [{'learning_rate': 0.17237563361425576, 'n_estimators': 565},
#  {'learning_rate': 0.3214436052390104, 'n_estimators': 223},
#  {'learning_rate': 0.2142536666067319, 'n_estimators': 987}]

# %%
len(best_params_list)
# Out:
# 3

# %%
# sub_df
features
# Out:
# ['Age', 'Sex', 'SmokingStatus', 'baselined_week', 'base_FVC']

# %%
sub_df
# Out:
#                        Patient  Weeks  Confidence  \
# 0    ID00419637202311204720264    -12         100
# 1    ID00419637202311204720264    -11         100
# 2    ID00419637202311204720264    -10         100
# 3    ID00419637202311204720264     -9         100
# 4    ID00419637202311204720264     -8         100
# ..                         ...    ...         ...
# 725  ID00426637202313170790466    129         100
# 726  ID00426637202313170790466    130         100
# 727  ID00426637202313170790466    131         100
# 728  ID00426637202313170790466    132         100
# 729  ID00426637202313170790466    133         100
#
#                       Patient_Week   FVC    Percent  Age  Sex  SmokingStatus  \
# 0    ID00419637202311204720264_-12  3020  70.186855   73    1              1
# 1    ID00419637202311204720264_-11  3020  70.186855   73    1              1
# 2    ID00419637202311204720264_-10  3020  70.186855   73    1              1
# 3     ID00419637202311204720264_-9  3020  70.186855   73    1              1
# 4     ID00419637202311204720264_-8  3020  70.186855   73    1              1
# ..                             ...   ...        ...  ...  ...            ...
# 725  ID00426637202313170790466_129  2925  71.824968   73    1              2
# 726  ID00426637202313170790466_130  2925  71.824968   73    1              2
# 727  ID00426637202313170790466_131  2925  71.824968   73    1              2
# 728  ID00426637202313170790466_132  2925  71.824968   73    1              2
# 729  ID00426637202313170790466_133  2925  71.824968   73    1              2
#
#     Source
# 0     test
# 1     test
# 2     test
# 3     test
# 4     test
# ..     ...
# 725   test
# 726   test
# 727   test
# 728   test
# 729   test
#
# [730 rows x 10 columns]
